# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
r = np.arange(0, 2, 0.01)
theta = 2 * np.pi * r

# %% [markdown]
# ### Create a separate axe and put a subplot

# %%
ax = plt.subplot(111, projection='polar')
ax.plot(theta, r)
ax.set_rmax(2) # outer radial limit

# %% [markdown]
# ### Set the number of Ticks

# %%
ax = plt.subplot(111, projection='polar')
ax.plot(theta, r)
ax.set_rmax(2)
ax.set_rticks([0.5, 1, 1.5, 2]) # to set the radial ticks
# Out:
# [<matplotlib.projections.polar.RadialTick at 0x1cf2f977448>,
#  <matplotlib.projections.polar.RadialTick at 0x1cf2f9db388>,
#  <matplotlib.projections.polar.RadialTick at 0x1cf2f9ca9c8>,
#  <matplotlib.projections.polar.RadialTick at 0x1cf2f9dd388>]

# %% [markdown]
# ### Change the orientation of Tick lable

# %%
ax = plt.subplot(111, projection='polar')
ax.plot(theta, r)
ax.set_rmax(2)
ax.set_rticks([0.5, 1, 1.5, 2]) # to set the radial ticks
ax.set_rlabel_position(180)

# %% [markdown]
# ### Adding Title to the plot

# %%
ax = plt.subplot(111, projection='polar')
ax.plot(theta, r)
ax.set_rmax(2)
ax.set_rticks([0.5, 1, 1.5, 2]) # to set the radial ticks

ax.set_title("A line plot on a polar axis", fontsize=14)
plt.show()
