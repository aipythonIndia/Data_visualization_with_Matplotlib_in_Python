# %% [markdown]
# ### Importing Modules (Library)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Plotting first data

# %%
data = [1,2,3,4,5]
plt.plot(data)
plt.show()

# %% [markdown]
# ### Plotting X and Y data

# %%
x_data = [1,2,3,4,5]
y_data = [1, 4, 9, 16, 25]
plt.plot(x_data, y_data)
plt.show()
